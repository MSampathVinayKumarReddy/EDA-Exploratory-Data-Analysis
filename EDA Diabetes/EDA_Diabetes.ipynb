# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe().T
# Out:
#                           count        mean  ...        75%     max
# Pregnancies               768.0    3.845052  ...    6.00000   17.00
# Glucose                   768.0  120.894531  ...  140.25000  199.00
# BloodPressure             768.0   69.105469  ...   80.00000  122.00
# SkinThickness             768.0   20.536458  ...   32.00000   99.00
# Insulin                   768.0   79.799479  ...  127.25000  846.00
# BMI                       768.0   31.992578  ...   36.60000   67.10
# DiabetesPedigreeFunction  768.0    0.471876  ...    0.62625    2.42
# Age                       768.0   33.240885  ...   41.00000   81.00
# Outcome                   768.0    0.348958  ...    1.00000    1.00
#
# [9 rows x 8 columns]

# %% [markdown]
# ------------------------Most of the values in the dataframe are 0's
# Replace them with Nan values------------------------------

# %%
data_copy=data.copy(deep=True)

# %% [markdown]
# # We will create a copy of our dataframe and save it in data_copy and will compare them after data cleaning and EDA

# %%
data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
data_copy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data_copy.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c4fbb5dd0>,
# ...
#       dtype=object)

# %%
data_copy['Glucose'].fillna(data_copy['Glucose'].mean(),inplace=True)

# %%
data_copy['BloodPressure'].fillna(data_copy['BloodPressure'].mean(),inplace=True)

# %%
data_copy['SkinThickness'].fillna(data_copy['SkinThickness'].median(),inplace=True)

# %%
data_copy['Insulin'].fillna(data_copy['Insulin'].median(),inplace=True)

# %%
data_copy['BMI'].fillna(data_copy['BMI'].median(),inplace=True)

# %%
data_copy.hist(figsize=(16,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c4f709a50>,
# ...
#       dtype=object)

# %%
data_copy['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
sns.countplot('Outcome',data=data_copy)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Difference between data(uncleaned) & data_copy(cleaned)

# %% [markdown]
# # data (uncleaned)

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data.corr(),annot=True,cmap ='RdYlGn')

# %% [markdown]
# # data_copy (cleaned)

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data_copy.corr(),annot=True,cmap ='RdYlGn')
